# %%
import polars as pl

df = pl.read_csv("../movie_dataset/wiki_movie_plots_deduped.csv")
print(df.head())
# Out:
# shape: (5, 8)
# ┌─────────┬──────────────┬──────────────┬─────────────┬──────┬─────────┬─────────────┬─────────────┐
# │ Release ┆ Title        ┆ Origin/Ethni ┆ Director    ┆ Cast ┆ Genre   ┆ Wiki Page   ┆ Plot        │
# │ Year    ┆ ---          ┆ city         ┆ ---         ┆ ---  ┆ ---     ┆ ---         ┆ ---         │
# │ ---     ┆ str          ┆ ---          ┆ str         ┆ str  ┆ str     ┆ str         ┆ str         │
# │ i64     ┆              ┆ str          ┆             ┆      ┆         ┆             ┆             │
# ╞═════════╪══════════════╪══════════════╪═════════════╪══════╪═════════╪═════════════╪═════════════╡
# │ 1901    ┆ Kansas       ┆ American     ┆ Unknown     ┆ null ┆ unknown ┆ https://en. ┆ A bartender │
# │         ┆ Saloon       ┆              ┆             ┆      ┆         ┆ wikipedia.o ┆ is working  │
# │         ┆ Smashers     ┆              ┆             ┆      ┆         ┆ rg/wiki/…   ┆ at a sa…    │
# │ 1901    ┆ Love by the  ┆ American     ┆ Unknown     ┆ null ┆ unknown ┆ https://en. ┆ The moon,   │
# │         ┆ Light of the ┆              ┆             ┆      ┆         ┆ wikipedia.o ┆ painted     │
# │         ┆ Moon         ┆              ┆             ┆      ┆         ┆ rg/wiki/…   ┆ with a      │
# │         ┆              ┆              ┆             ┆      ┆         ┆             ┆ smili…      │
# │ 1901    ┆ The Martyred ┆ American     ┆ Unknown     ┆ null ┆ unknown ┆ https://en. ┆ The film,   │
# │         ┆ Presidents   ┆              ┆             ┆      ┆         ┆ wikipedia.o ┆ just over a │
# │         ┆              ┆              ┆             ┆      ┆         ┆ rg/wiki/…   ┆ minute l…   │
# │ 1901    ┆ Terrible     ┆ American     ┆ Unknown     ┆ null ┆ unknown ┆ https://en. ┆ Lasting     │
# │         ┆ Teddy, the   ┆              ┆             ┆      ┆         ┆ wikipedia.o ┆ just 61     │
# │         ┆ Grizzly Ki…  ┆              ┆             ┆      ┆         ┆ rg/wiki/…   ┆ seconds and │
# │         ┆              ┆              ┆             ┆      ┆         ┆             ┆ co…         │
# │ 1902    ┆ Jack and the ┆ American     ┆ George S.   ┆ null ┆ unknown ┆ https://en. ┆ The         │
# │         ┆ Beanstalk    ┆              ┆ Fleming,    ┆      ┆         ┆ wikipedia.o ┆ earliest    │
# │         ┆              ┆              ┆ Edwin S.    ┆      ┆         ┆ rg/wiki/…   ┆ known       │
# │         ┆              ┆              ┆ Po…         ┆      ┆         ┆             ┆ adaptation  │
# │         ┆              ┆              ┆             ┆      ┆         ┆             ┆ …           │
# └─────────┴──────────────┴──────────────┴─────────────┴──────┴─────────┴─────────────┴─────────────┘

# %%
processed_csv = pl.read_csv("../movie_dataset/processed_movie_plots.csv")
print(processed_csv.head())
# Out:
# shape: (5, 2)
# ┌───────────────────────────────┬─────────────────────────────────┐
# │ Title                         ┆ Plot                            │
# │ ---                           ┆ ---                             │
# │ str                           ┆ str                             │
# ╞═══════════════════════════════╪═════════════════════════════════╡
# │ Ringmaster                    ┆ The movie starts with Prince (… │
# │ Return of the Killer Tomatoes ┆ Set ten years after the events… │
# │ The Heritage of Love          ┆ The film is set in 2016. Andre… │
# │ Paigham                       ┆ The movie traces the lives of … │
# │ Saadaram                      ┆ Though a lawyer by profession,… │
# └───────────────────────────────┴─────────────────────────────────┘

# %%
# Number of words in each plot
df = df.with_columns(pl.col("Plot").str.split(" ").list.len().alias("Word_Count"))
print(df.select(pl.col("Word_Count")).describe())
# Out:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ Word_Count │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 34886.0    │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 369.688242 │
# │ std        ┆ 313.240182 │
# │ min        ┆ 2.0        │
# │ 25%        ┆ 121.0      │
# │ 50%        ┆ 282.0      │
# │ 75%        ┆ 576.0      │
# │ max        ┆ 6731.0     │
# └────────────┴────────────┘
